# %%
# Title: Exercise 2.2
# Author: James Sneddon
# Date: 14 December 2025
# Modified By: James Sneddon
# Description: This program 
# filename: /Users/jamessneddon/Downloads/week2data/car_data.csv / /Users/jamessneddon/Downloads/week2data/housing_data.csv

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 6
#       4 import numpy as np
#       5 get_ipython().system('pip install scikit-learn')
# ----> 6 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
mpg_df = pd.read_csv('/Users/jamessneddon/Downloads/week2data/car_data.csv')

# %%
plt.scatter(mpg_df["weight"], mpg_df["hwy_mpg"])
plt.xlabel("Weight")
plt.ylabel("Highway MPG")
plt.show()
#create scatterplot with labels

# %%
#2.) based on the scatterplot there is a negative correlation between highway mpg and weight.

# %%
#3.) negative

# %%
#4.) for every lb added, the highway mpg decreases by -0.05 on average

# %%
m = -0.01
b = 56

x = mpg_df["weight"]
y = m * x + b
plt.plot(x, y, color="red")

plt.xlabel("Weight")
plt.ylabel("Highway MPG")
plt.scatter(mpg_df["weight"], mpg_df["hwy_mpg"])
plt.show()
#5.) adjusted m and b for the linear equation until it seemed to be 1/2 above and 1/2 below the line

# %%
m, b = np.polyfit(x, y, 1)
print("Slope:", m)
print("Intercept:", b)
# Out:
# Slope: -0.009999999999999998
# Intercept: 56.0

# %%
#7.) The rmse between the two lines was ≈ 0. I wouldn't have expected my prediction to be this accurate

# %%
sample_mpg = -0.009999999999999998 * 3200 + 56
print(sample_mpg)
#8.) used equation from question #7 to print predicted mpg
# Out:
# 24.000000000000004
