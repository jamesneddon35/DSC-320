# %%
# Title: Assignment 2.15
# Author: James Sneddon
# Date: 10 December 2025
# Modified By: James Sneddon
# Description: This program reduces the dataset into customer/subscriber sections for rides on September 1st, 2020.
# Citi Bike system data found here: https://s3.amazonaws.com/tripdata/index.html
# filename: 202009-citibike-tripdata.csv.zip

# %%
import pandas as pd

# %%
citybike_df = pd.read_csv('/Users/jamessneddon/Downloads/JC-202009-citibike-tripdata.csv')

# %%
citybike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           222  2020-09-01 00:15:58.6470  2020-09-01 00:19:40.8750
# 1           193  2020-09-01 00:49:00.7370  2020-09-01 00:52:14.3640
# 2           273  2020-09-01 00:51:44.5870  2020-09-01 00:56:17.7160
# 3          1419  2020-09-01 00:52:48.3160  2020-09-01 01:16:28.0490
# 4           254  2020-09-01 00:56:16.7170  2020-09-01 01:00:31.0870
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3640     Journal Square               40.733670
# 2              3191           Union St               40.718211
# 3              3203      Hamilton Park               40.727596
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3276  Marin Light Rail
# ...

# %%
citybike20200901_df = citybike_df[citybike_df['starttime'] <= '2020-09-02']
#filter dates to only include startimes on September 1st, 2020

# %%
citybike_df['usertype'].value_counts()
#filter user types to count # of subscribers, customers, and other
# Out:
# usertype
# Subscriber    35284
# Customer      18549
# Name: count, dtype: int64
